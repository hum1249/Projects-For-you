# %%
import numpy as numpy
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\RG\OneDrive\Desktop\flexon data sets\day 1 data sets\tested.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset.shape
# Out:
# (418, 12)

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
import matplotlib.pyplot as plt
missing_percent = (dataset.isnull().sum() / len(dataset)) * 100
missing_percent = missing_percent[missing_percent > 0]  # Only include columns with missing values

missing_percent.plot(kind='bar', color='orange', figsize=(10, 6))
plt.title("Percentage of Missing Values by Column")
plt.xlabel("Columns")
plt.ylabel("Percentage of Missing Values")
plt.show()

# %%
dataset["Fare"] = dataset["Fare"].fillna(dataset["Fare"].mean())

# %%
dataset["Fare"]
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
print(dataset["Fare"].isnull().sum())  # Counts the missing (NaN) values
# Out:
# 0

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
dataset["Age"]=dataset["Age"].fillna(dataset["Age"].mean())

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#### Down below i am performing the number of occurences of the fare prices regarding to the pclass using groupby method###

# %%
dataset_groupy=dataset.groupby(['Pclass','Fare','Sex','Embarked']).size()

# %%
print(dataset_groupy)
# Out:
# Pclass  Fare     Sex     Embarked
# 1       0.0000   male    S           2
#         25.7000  female  S           1
#         25.7417  male    C           1
#         26.0000  male    C           1
#                          S           5
#                                     ..
# 3       46.9000  female  S           1
#                  male    S           1
#         56.4958  male    S           1
#         69.5500  female  S           2
#                  male    S           2
# Length: 224, dtype: int64

# %%
###GROUP BY two coloumns and performing agg functions on them###

# %%
dataset.groupby(["Pclass","Survived"]).agg({"Age":"mean","Fare":"sum"})
# Out:
#                        Age       Fare
# Pclass Survived
# 1      0         39.261546  4308.4334
#        1         40.890904  5779.5584
# 2      0         30.898260  1271.6332
#        1         24.573086   793.1625
# 3      0         26.493421  1729.2750
#        1         25.273153   988.9293

# %%
pivot_table=dataset.pivot_table(index="Pclass",values=['Age','Fare'],aggfunc={"Age":'mean','Fare':'sum'})

# %%
print(pivot_table)
# Out:
#               Age        Fare
# Pclass
# 1       40.022928  10087.9918
# 2       28.857881   2064.7957
# 3       26.090397   2718.2043

# %%
pivot_table.plot(kind='bar')
plt.title('Total Fare by Pclass')
plt.ylabel('Total Fare')
plt.xlabel('Pclass')
plt.show()

# %%
###Melt table which is used to convert the ling data into wide data format"

# %%
dataset_melted = pd.melt(dataset, id_vars=['PassengerId', 'Survived'], var_name='Variable', value_name='Value')

# %%
dataset_melted.head()
# Out:
#    PassengerId  Survived Variable Value
# 0          892         0   Pclass     3
# 1          893         1   Pclass     3
# 2          894         0   Pclass     2
# 3          895         0   Pclass     3
# 4          896         1   Pclass     3

# %%
###Creating a data frame for carrying out merge union and concatenate###

# %%
dataset.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
###splitting the dataset in to two hafs then performing concatenation,merging and join on them###

# %%
###CONCATENATION###

# %%
dataset2=dataset.iloc[:209]
dataset3=dataset.iloc[209:]

# %%
dataset2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
dataset3.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 209         1101         0       3
# 210         1102         0       3
# 211         1103         0       3
# 212         1104         0       2
# 213         1105         1       2
#
#                                              Name     Sex       Age  SibSp  \
# 209                            Delalic, Mr. Redjo    male  25.00000      0
# 210                   Andersen, Mr. Albert Karvin    male  32.00000      0
# 211                             Finoli, Mr. Luigi    male  30.27259      0
# 212                     Deacon, Mr. Percy William    male  17.00000      0
# 213  Howard, Mrs. Benjamin (Ellen Truelove Arman)  female  60.00000      1
#
#      Parch              Ticket     Fare Embarked
# 209      0              349250   7.8958        S
# 210      0              C 4001  22.5250        S
# 211      0  SOTON/O.Q. 3101308   7.0500        S
# 212      0        S.O.C. 14879  73.5000        S
# 213      0               24065  26.0000        S

# %%
dataset_concatenated_coloumnwise=pd.concat([dataset2,dataset3],axis=1)

# %%
dataset_concatenated_rowwise=pd.concat([dataset2,dataset3],axis=0)

# %%
dataset_concatenated_rowwise.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
dataset_concatenated_coloumnwise.head()
# Out:
#    PassengerId Survived  Pclass                                          Name  \
# 0        892.0      0.0     3.0                              Kelly, Mr. James
# 1        893.0      1.0     3.0              Wilkes, Mrs. James (Ellen Needs)
# 2        894.0      0.0     2.0                     Myles, Mr. Thomas Francis
# 3        895.0      0.0     3.0                              Wirz, Mr. Albert
# 4        896.0      1.0     3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age SibSp  Parch   Ticket     Fare  ... Survived  Pclass  Name  \
# 0    male  34.5   0.0    0.0   330911   7.8292  ...      NaN     NaN   NaN
# 1  female  47.0   1.0    0.0   363272   7.0000  ...      NaN     NaN   NaN
# 2    male  62.0   0.0    0.0   240276   9.6875  ...      NaN     NaN   NaN
# 3    male  27.0   0.0    0.0   315154   8.6625  ...      NaN     NaN   NaN
# 4  female  22.0   1.0    1.0  3101298  12.2875  ...      NaN     NaN   NaN
#
# ...

# %%
###MERGE###

# %%
dataset_merged=pd.merge(dataset2,dataset3,on='Pclass',how='inner')

# %%
###Join###

# %%
dataset2 = dataset2.set_index('PassengerId')   
dataset3 = dataset3.set_index('PassengerId')

# %%
dataset_joined = dataset2.join(dataset3, how="outer", lsuffix='_left', rsuffix='_right')

# %%
###Creating Stack###

# %%
stacked_dataset=dataset.set_index(['PassengerId', 'Survived']).stack()

# %%
stacked_dataset
# Out:
# PassengerId  Survived
# 892          0         Pclass                     3
#                        Name        Kelly, Mr. James
#                        Sex                     male
#                        Age                     34.5
#                        SibSp                      0
#                                          ...
# 1309         0         SibSp                      1
#                        Parch                      1
#                        Ticket                  2668
#                        Fare                 22.3583
#                        Embarked                   C
# Length: 3762, dtype: object
